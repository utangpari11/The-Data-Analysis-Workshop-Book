# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# load hourly data
hourly_data = pd.read_csv('https://raw.githubusercontent.com/utangpari11/The-Data-Analysis-Workshop-Book/main/Bike-Sharing-Dataset/hour.csv')

# %%
hourly_data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
print('Shape of data: ',hourly_data.shape) 
#Gives number of rows,columns
# Out:
# Shape of data:  (17379, 17)

# %%
len(hourly_data.axes[0]), len(hourly_data.axes[1])
# Out:
# (17379, 17)

# %%
#Check for missing values
print('Number of missing values are:',hourly_data.isnull().sum().sum())
# Out:
# Number of missing values are: 0

# %%
hourly_data.describe()
#Returns Statistical information of the data
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
hourly_data.describe().T
#Returns Statistical information of the data, but after Transpose of the data
# Out:
#               count         mean          std   min        25%        50%  \
# instant     17379.0  8690.000000  5017.029500  1.00  4345.5000  8690.0000
# season      17379.0     2.501640     1.106918  1.00     2.0000     3.0000
# yr          17379.0     0.502561     0.500008  0.00     0.0000     1.0000
# mnth        17379.0     6.537775     3.438776  1.00     4.0000     7.0000
# hr          17379.0    11.546752     6.914405  0.00     6.0000    12.0000
# holiday     17379.0     0.028770     0.167165  0.00     0.0000     0.0000
# weekday     17379.0     3.003683     2.005771  0.00     1.0000     3.0000
# workingday  17379.0     0.682721     0.465431  0.00     0.0000     1.0000
# weathersit  17379.0     1.425283     0.639357  1.00     1.0000     1.0000
# temp        17379.0     0.496987     0.192556  0.02     0.3400     0.5000
# atemp       17379.0     0.475775     0.171850  0.00     0.3333     0.4848
# hum         17379.0     0.627229     0.192930  0.00     0.4800     0.6300
# ...

# %%
hourly_data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# The data is not in any meaningful format, so preprocessing of the data comes for further working.

# %% [markdown]
# **temporal features**
#
#  1. **dteday** - Represents date
#  2. **season** -
#    1:Spring, 2:Summer, 3:Fall, 4:Winter
#  3. **yr** - 0: 2011, 1:2012
#  4. **mnth** - Month from 1 to 12
#  5. **hr** - hours from 0 to 23
#  6. **holiday** - it is holiday(1) or not (0)
#  7. **weekday** - 0 to 6
#  8. **workingday** - if day not weekend or holiday - 1, else 0

# %% [markdown]
# **weather related features**
#
#  1. **weathersit** -
#     - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 	- 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 	- 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#     - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
#  2. **temp** - in *C
#  3. **atemp** - Feeling temp in *C
#  4. **hum** - humidity
#  5. **windspeed** -

# %% [markdown]
# **record related features**
#
#  1. **casual** - count of casual users
#  2. **registered** - count of registered users
#  3. **cnt** - count of total rental bikes including both casual and registered

# %% [markdown]
# decode the data into human readable format

# %%
preprocessed_data = hourly_data.copy() #Copy the original data into preprocessed_data
#encoding of 'season' column
season_mapping = {1: 'winter',2: 'spring', 3: 'summer', 4: 'fall'}
yr_mapping = {0: 2011, 1: 2012}
weekday_mapping = {0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday'}
weather_mapping = {1: 'clear', 2: 'cloudy', 3: 'light_rain_snow', 4: 'heavy_rain_snow'}

# %%
def dataEncoding():
    preprocessed_data['season'] = preprocessed_data['season'].apply(lambda x:season_mapping[x])
    preprocessed_data['yr'] = preprocessed_data['yr'].apply(lambda x:yr_mapping[x])
    preprocessed_data['weekday'] = preprocessed_data['weekday'].apply(lambda x:weekday_mapping[x])
    preprocessed_data['weathersit'] = preprocessed_data['weathersit'].apply(lambda x: weather_mapping[x])
    preprocessed_data['windspeed'] = preprocessed_data['windspeed']*67
    preprocessed_data['hum'] = preprocessed_data['hum']*100

# %%
dataEncoding()

# %%
preprocessed_data[['season', 'yr', 'weekday', 'weathersit', 'hum', 'windspeed']].sample(10,random_state=123)
# Out:
#        season    yr    weekday       weathersit   hum  windspeed
# 5792   summer  2011   Saturday            clear  74.0     8.9981
# 7823     fall  2011     Sunday            clear  43.0    31.0009
# 15426    fall  2012    Tuesday           cloudy  77.0     6.0032
# 15028    fall  2012     Sunday            clear  51.0    22.0028
# 12290  spring  2012     Friday           cloudy  89.0    12.9980
# 3262   spring  2011     Friday            clear  64.0     7.0015
# 10763  spring  2012   Thursday            clear  42.0    23.9994
# 12384  spring  2012    Tuesday  light_rain_snow  82.0    11.0014
# 6051   summer  2011  Wednesday            clear  52.0    19.0012
# 948    winter  2011   Saturday            clear  80.0     0.0000
